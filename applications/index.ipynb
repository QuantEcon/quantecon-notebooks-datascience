# %% [markdown]
# # Applications
#
# In this part of the course, we will begin to apply the skills that you have learned. This
# includes using familiar tools in new applications and learning new tools that can be used for
# special types of analysis.
#
# <div class="toctree">
#
# - [Data Visualization: Rules and Guidelines](visualization_rules.html)
#   - [Introduction](visualization_rules.html#introduction)
#   - [Steps to Creating Effective Charts](visualization_rules.html#steps-to-creating-effective-charts)
#   - [Visualization Types](visualization_rules.html#visualization-types)
#   - [Color in Plots](visualization_rules.html#color-in-plots)
#   - [Visualization Rules](visualization_rules.html#visualization-rules)
#   - [References](visualization_rules.html#references)
#   - [Exercises](visualization_rules.html#exercises)
# - [Regression](regression.html)
#   - [Introduction to Regression](regression.html#introduction-to-regression)
#   - [Linear Regression](regression.html#linear-regression)
#   - [Lasso Regression](regression.html#lasso-regression)
#   - [Random Forests](regression.html#random-forests)
#   - [Neural Networks](regression.html#neural-networks)
#   - [References](regression.html#references)
#   - [Exercises](regression.html#exercises)
# - [Case Study: Recidivism](recidivism.html)
#   - [Introduction to Recidivism](recidivism.html#introduction-to-recidivism)
#   - [Data Description](recidivism.html#data-description)
#   - [Descriptive Statistics](recidivism.html#descriptive-statistics)
#   - [Regression](recidivism.html#regression)
#   - [References](recidivism.html#references)
#   - [Exercises](recidivism.html#exercises)
# - [Mapping in Python](maps.html)
#   - [Mapping in Python](maps.html#id1)
#   - [Case Study: Voting in Wisconsin](maps.html#case-study-voting-in-wisconsin)
# - [Classification](classification.html)
#   - [Introduction to Classification](classification.html#introduction-to-classification)
#   - [Warmup Example: Logistic Regression](classification.html#warmup-example-logistic-regression)
#   - [Model Evaluation](classification.html#model-evaluation)
#   - [Neural Network Classifiers](classification.html#neural-network-classifiers)
#   - [Application: Predicting US Recessions](classification.html#application-predicting-us-recessions)
#   - [Exercises](classification.html#exercises)
# - [Working with Text](working_with_text.html)
#   - [Introduction](working_with_text.html#introduction)
#   - [Avalanches](working_with_text.html#avalanches)
#   - [Predicting Incidents from Text](working_with_text.html#predicting-incidents-from-text)
#   - [Unsupervised Learning](working_with_text.html#unsupervised-learning)
#   - [Exercises](working_with_text.html#exercises)
# - [Machine Learning in Economics](ml_in_economics.html)
#   - [Introduction](ml_in_economics.html#introduction)
#   - [Prediction Policy](ml_in_economics.html#prediction-policy)
#   - [Estimation of Nuisance Functions](ml_in_economics.html#estimation-of-nuisance-functions)
#   - [Heterogeneous Effects](ml_in_economics.html#heterogeneous-effects)
#   - [References](ml_in_economics.html#references)
# - [Heterogeneous Effects](heterogeneity.html)
#   - [Background and Data](heterogeneity.html#background-and-data)
#   - [Potential Outcomes and Treatment Effects](heterogeneity.html#potential-outcomes-and-treatment-effects)
#   - [Generic Machine Learning Inference](heterogeneity.html#generic-machine-learning-inference)
#   - [Causal Trees and Forests](heterogeneity.html#causal-trees-and-forests)
#   - [References](heterogeneity.html#references)
