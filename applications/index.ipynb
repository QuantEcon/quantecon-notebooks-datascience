# %% [markdown]
# # Applications
#
# In this part of the course, we will begin to apply the skills that you have learned. This
# includes using familiar tools in new applications and learning new tools that can be used for
# special types of analysis.
#
# <div class="toctree">
#
# - [Data Visualization: Rules and Guidelines](visualization_rules.ipynb)
#   - [Introduction](visualization_rules.ipynb#introduction)
#   - [Steps to Creating Effective Charts](visualization_rules.ipynb#steps-to-creating-effective-charts)
#   - [Visualization Types](visualization_rules.ipynb#visualization-types)
#   - [Color in Plots](visualization_rules.ipynb#color-in-plots)
#   - [Visualization Rules](visualization_rules.ipynb#visualization-rules)
#   - [References](visualization_rules.ipynb#references)
#   - [Exercises](visualization_rules.ipynb#exercises)
# - [Regression](regression.ipynb)
#   - [Introduction to Regression](regression.ipynb#introduction-to-regression)
#   - [Linear Regression](regression.ipynb#linear-regression)
#   - [Lasso Regression](regression.ipynb#lasso-regression)
#   - [Random Forests](regression.ipynb#random-forests)
#   - [Neural Networks](regression.ipynb#neural-networks)
#   - [References](regression.ipynb#references)
#   - [Exercises](regression.ipynb#exercises)
# - [Case Study: Recidivism](recidivism.ipynb)
#   - [Introduction to Recidivism](recidivism.ipynb#introduction-to-recidivism)
#   - [Data Description](recidivism.ipynb#data-description)
#   - [Descriptive Statistics](recidivism.ipynb#descriptive-statistics)
#   - [Regression](recidivism.ipynb#regression)
#   - [References](recidivism.ipynb#references)
#   - [Exercises](recidivism.ipynb#exercises)
# - [Mapping in Python](maps.ipynb)
#   - [Mapping in Python](maps.ipynb#id1)
#   - [Case Study: Voting in Wisconsin](maps.ipynb#case-study-voting-in-wisconsin)
# - [Classification](classification.ipynb)
#   - [Introduction to Classification](classification.ipynb#introduction-to-classification)
#   - [Warmup Example: Logistic Regression](classification.ipynb#warmup-example-logistic-regression)
#   - [Model Evaluation](classification.ipynb#model-evaluation)
#   - [Neural Network Classifiers](classification.ipynb#neural-network-classifiers)
#   - [Application: Predicting US Recessions](classification.ipynb#application-predicting-us-recessions)
#   - [Exercises](classification.ipynb#exercises)
# - [Working with Text](working_with_text.ipynb)
#   - [Introduction](working_with_text.ipynb#introduction)
#   - [Avalanches](working_with_text.ipynb#avalanches)
#   - [Predicting Incidents from Text](working_with_text.ipynb#predicting-incidents-from-text)
#   - [Unsupervised Learning](working_with_text.ipynb#unsupervised-learning)
#   - [Exercises](working_with_text.ipynb#exercises)
# - [Machine Learning in Economics](ml_in_economics.ipynb)
#   - [Introduction](ml_in_economics.ipynb#introduction)
#   - [Prediction Policy](ml_in_economics.ipynb#prediction-policy)
#   - [Estimation of Nuisance Functions](ml_in_economics.ipynb#estimation-of-nuisance-functions)
#   - [Heterogeneous Effects](ml_in_economics.ipynb#heterogeneous-effects)
#   - [References](ml_in_economics.ipynb#references)
# - [Heterogeneous Effects](heterogeneity.ipynb)
#   - [Background and Data](heterogeneity.ipynb#background-and-data)
#   - [Potential Outcomes and Treatment Effects](heterogeneity.ipynb#potential-outcomes-and-treatment-effects)
#   - [Generic Machine Learning Inference](heterogeneity.ipynb#generic-machine-learning-inference)
#   - [Causal Trees and Forests](heterogeneity.ipynb#causal-trees-and-forests)
#   - [References](heterogeneity.ipynb#references)
