# %% [markdown]
# # pandas
#
# This section of the workshop covers data ingestion, cleaning,
# manipulation, analysis, and visualization in Python.
#
# We build on the skills learned in the [Python
# fundamentals](../python_fundamentals/index.html) section and teach the
# [pandas](https://pandas.pydata.org) library.
#
# At the end of this section, you will be able to:
#
# - Access data stored in a variety of formats
# - Combine multiple datasets based on observations that link them
#   together
# - Perform custom operations on tables of data
# - Use the split-apply-combine method for analyzing sub-groups of data
# - Automate static analysis on changing data
# - Produce publication quality visualizations
#
#
# In the end, our goal with this section is to provide you the
# necessary skills to – at a minimum – **immediately** replicate your current
# data analysis workflow in Python with no loss of total (computer +
# human) time.
#
# This is a lower bound on the benefits you should expect to receive by
# studying this section.
#
# The expression “practice makes perfect” is especially true here.
#
# As you work with these tools, both the time to write and the time to run
# your programs will fall dramatically.
#
# <div class="toctree">
#
# - [Introduction](intro.html)
#   - [pandas](intro.html#pandas)
#   - [Series](intro.html#series)
#   - [DataFrame](intro.html#dataframe)
#   - [Data Types](intro.html#data-types)
#   - [Changing DataFrames](intro.html#changing-dataframes)
#   - [Exercises](intro.html#exercises)
# - [Basic Functionality](basics.html)
#   - [State Unemployment Data](basics.html#state-unemployment-data)
#   - [Dates in pandas](basics.html#dates-in-pandas)
#   - [DataFrame Aggregations](basics.html#dataframe-aggregations)
#   - [Transforms](basics.html#transforms)
#   - [Boolean Selection](basics.html#boolean-selection)
#   - [Exercises](basics.html#exercises)
# - [The Index](the_index.html)
#   - [So What is this Index?](the_index.html#so-what-is-this-index)
#   - [Setting the Index](the_index.html#setting-the-index)
#   - [Re-setting the Index](the_index.html#re-setting-the-index)
#   - [Choose the Index Carefully](the_index.html#choose-the-index-carefully)
#   - [Exercises](the_index.html#exercises)
# - [Storage Formats](storage_formats.html)
#   - [File Formats](storage_formats.html#file-formats)
#   - [Writing DataFrames](storage_formats.html#writing-dataframes)
#   - [Reading Files into DataFrames](storage_formats.html#reading-files-into-dataframes)
#   - [Practice](storage_formats.html#practice)
# - [Cleaning Data](data_clean.html)
#   - [Cleaning Data](data_clean.html#id1)
#   - [String Methods](data_clean.html#string-methods)
#   - [Type Conversions](data_clean.html#type-conversions)
#   - [Missing Data](data_clean.html#missing-data)
#   - [Case Study](data_clean.html#case-study)
#   - [Appendix: Performance of `.str` Methods](data_clean.html#appendix-performance-of-str-methods)
#   - [Exercises](data_clean.html#exercises)
# - [Reshape](reshape.html)
#   - [Tidy Data](reshape.html#tidy-data)
#   - [Reshaping your Data](reshape.html#reshaping-your-data)
#   - [Long vs Wide](reshape.html#long-vs-wide)
#   - [`set_index`, `reset_index`, and Transpose](reshape.html#set-index-reset-index-and-transpose)
#   - [`stack` and `unstack`](reshape.html#stack-and-unstack)
#   - [`melt`](reshape.html#melt)
#   - [`pivot` and `pivot_table`](reshape.html#pivot-and-pivot-table)
#   - [Visualizing Reshaping](reshape.html#visualizing-reshaping)
#   - [Exercises](reshape.html#exercises)
# - [Merge](merge.html)
#   - [Combining Datasets](merge.html#combining-datasets)
#   - [`pd.concat`](merge.html#pd-concat)
#   - [`pd.merge`](merge.html#pd-merge)
#   - [Arguments to `merge`](merge.html#arguments-to-merge)
#   - [`df.join`](merge.html#df-join)
#   - [Case Study](merge.html#case-study)
#   - [Extra Example: Airline Delays](merge.html#extra-example-airline-delays)
#   - [Visualizing Merge Operations](merge.html#visualizing-merge-operations)
#   - [Exercises](merge.html#exercises)
# - [GroupBy](groupby.html)
#   - [Split-Apply-Combine](groupby.html#split-apply-combine)
#   - [Case Study: Airline Delays](groupby.html#case-study-airline-delays)
#   - [Exercise: Cohort Analysis using Shopify Data](groupby.html#exercise-cohort-analysis-using-shopify-data)
#   - [Exercises](groupby.html#exercises)
# - [Time series](timeseries.html)
#   - [Intro](timeseries.html#intro)
#   - [Parsing Strings as Dates](timeseries.html#parsing-strings-as-dates)
#   - [Date Formatting](timeseries.html#date-formatting)
#   - [Extracting Data](timeseries.html#extracting-data)
#   - [Accessing Date Properties](timeseries.html#accessing-date-properties)
#   - [Leads and Lags: `df.shift`](timeseries.html#leads-and-lags-df-shift)
#   - [Rolling Computations: `.rolling`](timeseries.html#rolling-computations-rolling)
#   - [Changing Frequencies: `.resample`](timeseries.html#changing-frequencies-resample)
#   - [Optional: API keys](timeseries.html#optional-api-keys)
#   - [Exercises](timeseries.html#exercises)
# - [Intermediate Plotting](matplotlib.html)
#   - [Introduction](matplotlib.html#introduction)
#   - [The Want Operator: Replicate a Professional Figure](matplotlib.html#the-want-operator-replicate-a-professional-figure)
#   - [Data](matplotlib.html#data)
#   - [Warmup](matplotlib.html#warmup)
#   - [Data Cleaning](matplotlib.html#data-cleaning)
#   - [Constructing the Plot](matplotlib.html#constructing-the-plot)
#   - [Saving the Figure](matplotlib.html#saving-the-figure)
#   - [Exercises](matplotlib.html#exercises)
